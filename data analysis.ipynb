# %%
import pandas as pd

# %%
dataset=pd.read_csv("Downloads/movie (1).csv")

# %%
dataset
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
dataset.duration.sum()
# Out:
# 524852.0

# %%
dataset
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
25/5
# Out:
# 5.0

# %%
import matplotlib.pyplot as plt

# %%
duration=dataset['duration']
duration1=duration.head(200)

# %%
plt.plot(duration1,'co')

# %%
x=dataset['movie_title']
x
# Out:
# 0                                           Avatar
# 1         Pirates of the Caribbean: At World's End
# 2                                          Spectre
# 3                            The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens
#                            ...
# 4911                       Signed Sealed Delivered
# 4912                                 The Following
# 4913                          A Plague So Pleasant
# 4914                              Shanghai Calling
# 4915                             My Date with Drew
# Name: movie_title, Length: 4916, dtype: object

# %%
x.describe()
# Out:
# count       4916
# unique      4916
# top       Avatar
# freq           1
# Name: movie_title, dtype: object

# %%
x=dataset.duration.unique
x
# Out:
# <bound method Series.unique of 0       178.0
# 1       169.0
# 2       148.0
# 3       164.0
# 4         NaN
#         ...
# 4911     87.0
# 4912     43.0
# 4913     76.0
# 4914    100.0
# 4915     90.0
# Name: duration, Length: 4916, dtype: float64>

# %%
dataset.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
likes=dataset['movie_facebook_likes']
x=likes>1000
x.sum()
# Out:
# 1276

# %%
shape1=dataset.shape

# %%
(dataset.isnull().sum().sum())/(shape1[0]*shape1[1])
# Out:
# 0.019281064744856444

# %%
dataset.isnull().sum().sum()
# Out:
# 2654

# %%
x=duration.shape
x
# Out:
# (4916,)

# %%
(duration.isnull().sum().sum())/(shape1[0]*shape1[1])
# Out:
# 0.00010897361385563176

# %%
data=dataset.set_index('duration') #make new dataset with the new index

# %%
data.isnull().sum().sum()
# Out:
# 2639

# %%
y=data.fillna(0) #fill the null value with 0

# %%
y.isnull().sum().sum()
# Out:
# 0

# %%
x=data.dropna(axis=0) #1:index 0:row

# %%
x=data.dropna(how='any') #any-->drop the column that has null values
#all-->drop the comlumn with all missing values

# %%
duration=dataset.duration.fillna(duration.mean()) 
#mean-->average, mode-->most repeated value, random choice-->random num

# %%
duration.isnull().sum()
# Out:
# 0

# %%
dataset.iloc[4,4] #row,column [[0,0],0]/[0,[0,0]] 
#[0:0]--> range
#iloc -->integers
# Out:
# 131.0

# %%
dataset.loc[2,'duration'] #loc-->for names
# Out:
# 148.0

# %%
weather=pd.read_csv('Downloads/DailyDelhiClimateTest.csv')

# %%
weather
# Out:
#            date   meantemp   humidity  wind_speed  meanpressure
# 0    2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1    2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2    2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3    2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4    2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ..          ...        ...        ...         ...           ...
# 109  2017-04-20  34.500000  27.500000    5.562500    998.625000
# 110  2017-04-21  34.250000  39.375000    6.962500    999.875000
# 111  2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 112  2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 113  2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 5 columns]

# %%
weather=weather.set_index('date')

# %%
weather.head(5)
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2017-01-01  15.913043  85.869565    2.743478     59.000000
# 2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 2017-01-05  18.388889  74.944444    3.300000   1014.333333

# %%
x=weather.groupby('wind_speed')['humidity'].sum().sort_values().tail(20)
#1st-->as index ,2nd-->as feature (dataframe with two columns)
#sort_values-->order from minimum to maximum

# %%
import matplotlib.pyplot as plt
x.plot(kind='bar',color='pink')
# Out:
# <AxesSubplot:xlabel='wind_speed'>

# %%
#between_time('','',include_end=Fales-->the end time is out )
#at_time('')

# %%
import pandas as pd
college=pd.read_csv('Downloads/college.csv')

# %%
college
# Out:
#                                                  INSTNM              CITY  \
# 0                              Alabama A & M University            Normal
# 1                   University of Alabama at Birmingham        Birmingham
# 2                                    Amridge University        Montgomery
# 3                   University of Alabama in Huntsville        Huntsville
# 4                              Alabama State University        Montgomery
# ...                                                 ...               ...
# 7530         SAE Institute of Technology  San Francisco        Emeryville
# 7531                  Rasmussen College - Overland Park     Overland Park
# 7532  National Personal Training Institute of Cleveland  Highland Heights
# 7533  Bay Area Medical Academy - San Jose Satellite ...          San Jose
# 7534            Excel Learning Center-San Antonio South       San Antonio
#
#      STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# ...

# %%
college.CITY.value_counts()
# Out:
# New York             87
# Chicago              78
# Houston              72
# Los Angeles          56
# Miami                51
#                      ..
# Sparkill              1
# Brooklyn Heights      1
# Saint Bonaventure     1
# Paul Smiths           1
# Willingboro           1
# Name: CITY, Length: 2514, dtype: int64

# %%
"C:\Users\Lenovo\Downloads\Building_Permits (1).csv"
